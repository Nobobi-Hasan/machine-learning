# %%
import pandas as pd
from sklearn import tree

# %%
df =pd.read_csv('DataSets//shop data.csv')

# %%
df
# Out:
#       age  income  gender m_status buys
# 0     <25    high    male   single   no
# 1     <25    high    male  married   no
# 2   25-35    high    male   single  yes
# 3     >35  medium    male   single  yes
# 4     >35     low  female   single  yes
# 5     >35     low  female   single   no
# 6   25-35     low  female  married  yes
# 7     <25  medium    male  married   no
# 8     <25     low  female   single  yes
# 9     >35  medium  female  married  yes
# 10    <25  medium  female   single  yes
# 11  25-35  medium    male  married  yes
# 12  25-35    high  female   single  yes
# 13    >35  medium    male  married   no
# 14    <25    high    male   single   no

# %%
X_train = df.iloc[:,:-1]
# X_train = df[['height', 'weight', 'shoe size']]
X_train.head()
# Out:
#      age  income  gender m_status
# 0    <25    high    male   single
# 1    <25    high    male  married
# 2  25-35    high    male   single
# 3    >35  medium    male   single
# 4    >35     low  female   single

# %%
y_train = df.iloc[:,-1]
y_train.head()
# Out:
# 0     no
# 1     no
# 2    yes
# 3    yes
# 4    yes
# Name: buys, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

X_train = X_train.apply(LabelEncoder().fit_transform)
# X_train.age = LabelEncoder().fit_transform(X_train['age'])
# X_train.income = LabelEncoder().fit_transform(X_train['income'])
# X_train.gender = LabelEncoder().fit_transform(X_train['gender'])
# X_train.m_status = LabelEncoder().fit_transform(X_train['m_status'])
X_train.head()
# Out:
#    age  income  gender  m_status
# 0    1       0       1         1
# 1    1       0       1         0
# 2    0       0       1         1
# 3    2       2       1         1
# 4    2       1       0         1

# %%
# X_train = df_train[['feature1', 'feature2']]  # Training data with named columns
# model.fit(X_train, y_train)

model = tree.DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = model.predict([[1, 0, 1, 1]])
pred
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['no'], dtype=object)

# %%
from sklearn import tree

tree.plot_tree(model, filled = True, rounded = True, feature_names = X_train.columns)
# Out:
# [Text(0.3333333333333333, 0.9, 'age <= 0.5\ngini = 0.48\nsamples = 15\nvalue = [6, 9]'),
#  Text(0.2222222222222222, 0.7, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4444444444444444, 0.7, 'gender <= 0.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.2222222222222222, 0.5, 'age <= 1.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.1111111111111111, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3333333333333333, 0.3, 'income <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2222222222222222, 0.1, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4444444444444444, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6666666666666666, 0.5, 'age <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.5555555555555556, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7777777777777778, 0.3, 'm_status <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
# ...
